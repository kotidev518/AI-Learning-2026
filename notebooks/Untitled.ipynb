# %%
import numpy as np

# %%
a=np.array([
    [19,89],
    [6,7]
])
b=np.array([
    [2,5],
    [4,3]
           ])

print(type(b))
print(a@b)
# Out:
# <class 'numpy.ndarray'>
# [[394 362]
#  [ 40  51]]
